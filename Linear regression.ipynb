# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("Salary_dataset.csv") # first we need upload the dataset
dataset.head() # will shoe first 5 rows
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
x = dataset.iloc[:,0:1]
y = dataset.iloc[:,1]
x.head()
# Out:
#    Unnamed: 0
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
samplepredciton = model.predict([[1030]])
print(samplepredciton)
# Out:
# [327.16092296]
# C:\Users\dhivi\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
y_pred = model.predict(x_test) # predicting for all x_test
y_pred
# Out:
# array([9.40595915, 5.60430455, 8.13874095, 6.23791365, 3.3866727 ,
#        3.70347725])

# %%
y_test
# Out:
# 27    9.7
# 15    5.0
# 23    8.3
# 17    5.4
# 8     3.3
# 9     3.8
# Name: YearsExperience, dtype: float64

# %%
y_pred
# Out:
# array([9.40595915, 5.60430455, 8.13874095, 6.23791365, 3.3866727 ,
#        3.70347725])

# %%
list(zip(y_test,y_pred))
# Out:
# [(9.7, 9.405959152016546),
#  (5.0, 5.60430455015512),
#  (8.299999999999999, 8.138740951396072),
#  (5.4, 6.237913650465358),
#  (3.3000000000000003, 3.3866726990692873),
#  (3.8, 3.7034772492244064)]

# %%
import numpy as np

# Hypothetical housing dataset
areas = np.array([1000, 1030, 1060, 1090])  # House areas in square feet
prices = np.array([5618, 5201, 4779, 5245])  # House prices in dollars

# Example of a simple linear regression model (hypothetical coefficients)
m = 200  # slope
b = 50000  # intercept

# Make predictions
predicted_prices = m * areas + b

# Calculate squared differences
squared_diff = (prices - predicted_prices) ** 2

# Calculate mean squared error
mse = np.mean(squared_diff)

print("Actual Prices:", prices)
print("Predicted Prices:", predicted_prices)
print("Squared Differences:", squared_diff)
print("Mean Squared Error:", mse)
# Out:
# Actual Prices: [5618 5201 4779 5245]
# Predicted Prices: [250000 256000 262000 268000]
# Squared Differences: [ -406980220 -1524371039  1738133401   320713289]
# Mean Squared Error: 31873857.75

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print(f'R-squared score: {r2:.2f}')
# Out:
# R-squared score: 0.96

# %%
y_test
# Out:
# 27    9.7
# 15    5.0
# 23    8.3
# 17    5.4
# 8     3.3
# 9     3.8
# Name: YearsExperience, dtype: float64
